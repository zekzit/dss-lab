# %%
import itertools
from tree_from_assoc_rules import list_all_factors
from controller import generate_decision_tree
from tabulate import tabulate
import datetime

# %%
# Define all factors - Ref(3)
all_factors = ["stay", "length_of_stay", "country", "review_group", "room_type"]

# Read file of possible values
possible_factor_values = list_all_factors()

# %%
# All possible permutations of all factors - Ref(4)
all_factors_permutations = []
for length in range(2, len(all_factors) + 1):
    all_factors_permutations += list(itertools.permutations(all_factors, length))

print(all_factors_permutations)
# Out:
# [('stay', 'length_of_stay'), ('stay', 'country'), ('stay', 'review_group'), ('stay', 'room_type'), ('length_of_stay', 'stay'), ('length_of_stay', 'country'), ('length_of_stay', 'review_group'), ('length_of_stay', 'room_type'), ('country', 'stay'), ('country', 'length_of_stay'), ('country', 'review_group'), ('country', 'room_type'), ('review_group', 'stay'), ('review_group', 'length_of_stay'), ('review_group', 'country'), ('review_group', 'room_type'), ('room_type', 'stay'), ('room_type', 'length_of_stay'), ('room_type', 'country'), ('room_type', 'review_group'), ('stay', 'length_of_stay', 'country'), ('stay', 'length_of_stay', 'review_group'), ('stay', 'length_of_stay', 'room_type'), ('stay', 'country', 'length_of_stay'), ('stay', 'country', 'review_group'), ('stay', 'country', 'room_type'), ('stay', 'review_group', 'length_of_stay'), ('stay', 'review_group', 'country'), ('stay', 'review_group', 'room_type'), ('stay', 'room_type', 'length_of_stay'), ('stay', 'room_type', 'country'), ('stay', 'room_type', 'review_group'), ('length_of_stay', 'stay', 'country'), ('length_of_stay', 'stay', 'review_group'), ('length_of_stay', 'stay', 'room_type'), ('length_of_stay', 'country', 'stay'), ('length_of_stay', 'country', 'review_group'), ('length_of_stay', 'country', 'room_type'), ('length_of_stay', 'review_group', 'stay'), ('length_of_stay', 'review_group', 'country'), ('length_of_stay', 'review_group', 'room_type'), ('length_of_stay', 'room_type', 'stay'), ('length_of_stay', 'room_type', 'country'), ('length_of_stay', 'room_type', 'review_group'), ('country', 'stay', 'length_of_stay'), ('country', 'stay', 'review_group'), ('country', 'stay', 'room_type'), ('country', 'length_of_stay', 'stay'), ('country', 'length_of_stay', 'review_group'), ('country', 'length_of_stay', 'room_type'), ('country', 'review_group', 'stay'), ('country', 'review_group', 'length_of_stay'), ('country', 'review_group', 'room_type'), ('country', 'room_type', 'stay'), ('country', 'room_type', 'length_of_stay'), ('country', 'room_type', 'review_group'), ('review_group', 'stay', 'length_of_stay'), ('review_group', 'stay', 'country'), ('review_group', 'stay', 'room_type'), ('review_group', 'length_of_stay', 'stay'), ('review_group', 'length_of_stay', 'country'), ('review_group', 'length_of_stay', 'room_type'), ('review_group', 'country', 'stay'), ('review_group', 'country', 'length_of_stay'), ('review_group', 'country', 'room_type'), ('review_group', 'room_type', 'stay'), ('review_group', 'room_type', 'length_of_stay'), ('review_group', 'room_type', 'country'), ('room_type', 'stay', 'length_of_stay'), ('room_type', 'stay', 'country'), ('room_type', 'stay', 'review_group'), ('room_type', 'length_of_stay', 'stay'), ('room_type', 'length_of_stay', 'country'), ('room_type', 'length_of_stay', 'review_group'), ('room_type', 'country', 'stay'), ('room_type', 'country', 'length_of_stay'), ('room_type', 'country', 'review_group'), ('room_type', 'review_group', 'stay'), ('room_type', 'review_group', 'length_of_stay'), ('room_type', 'review_group', 'country'), ('stay', 'length_of_stay', 'country', 'review_group'), ('stay', 'length_of_stay', 'country', 'room_type'), ('stay', 'length_of_stay', 'review_group', 'country'), ('stay', 'length_of_stay', 'review_group', 'room_type'), ('stay', 'length_of_stay', 'room_type', 'country'), ('stay', 'length_of_stay', 'room_type', 'review_group'), ('stay', 'country', 'length_of_stay', 'review_group'), ('stay', 'country', 'length_of_stay', 'room_type'), ('stay', 'country', 'review_group', 'length_of_stay'), ('stay', 'country', 'review_group', 'room_type'), ('stay', 'country', 'room_type', 'length_of_stay'), ('stay', 'country', 'room_type', 'review_group'), ('stay', 'review_group', 'length_of_stay', 'country'), ('stay', 'review_group', 'length_of_stay', 'room_type'), ('stay', 'review_group', 'country', 'length_of_stay'), ('stay', 'review_group', 'country', 'room_type'), ('stay', 'review_group', 'room_type', 'length_of_stay'), ('stay', 'review_gr ...

# %%
# Hardcoded some constants
mcda_type = "rating"
hotel_name = "Amari Phuket"
rule_year = None
rule_month = None

# %%
print("all cases = " + str(len(all_factors_permutations)))
def collect_paths(node, route_nodes=[]):
    result = []
    has_child = len(node.children) > 0
    if has_child:
        for child_node in node.children:
            new_route_nodes = []
            new_route_nodes += route_nodes
            new_route_nodes.append(node)
            result += collect_paths(child_node, route_nodes=new_route_nodes)
    else:
        new_route_nodes = []
        new_route_nodes += route_nodes
        new_route_nodes.append(node)
        return [new_route_nodes]
    return result

# Generate decision tree for all permutations
count = 0
gen_count = 0
nodes = []
result_score_table = [["Outcome", "Factor_1", "Factor_2", "Factor_3", "Factor_4", "Factor_5", "Score"]]
for idx, permutation in enumerate(all_factors_permutations):
    # Calculate weights array
    factors_length = len(permutation)
    factor_weight = 1 / factors_length
    weights = [factor_weight for x in range(factors_length)]

    # Generate Decision Tree
    # print(permutation)
    gen_count += 1
    a = datetime.datetime.now()
    root_node = generate_decision_tree(mcda_type, list(permutation), weights, hotel_name=hotel_name,
                                       rule_year=rule_year, rule_month=rule_month)
    b = datetime.datetime.now()
    c = b - a
    print(str(gen_count) + ": " + str(c) + " - " + str(permutation))
    nodes.append(root_node)

    # Prototype: calculate score on each tree
    # print(RenderTree(root_node, style=AsciiStyle()).by_attr())
    paths = collect_paths(root_node)
    for p_idx, path in enumerate(paths):
        count += 1
        result_name = list(map(lambda k : k.name, path[1:]))
        weight_sum = sum(n.weight for n in path[1:])
        score_sum = sum(n.score for n in path[1:]) if weight_sum == 1 else 0
        result_row = [None] * 7
        result_row[0] = count
        result_row[1:5] = result_name + [None] * (5 - len(result_name))
        result_row[6] = score_sum
        result_score_table.append(result_row)
# Out:
# all cases = 320
# 1: 0:00:58.039750 - ('stay', 'length_of_stay')
# 2: 0:00:21.099972 - ('stay', 'country')
# 3: 0:00:19.018473 - ('stay', 'review_group')
# 4: 0:00:16.675163 - ('stay', 'room_type')
# 5: 0:00:05.155911 - ('length_of_stay', 'stay')
# 6: 0:00:02.673826 - ('length_of_stay', 'country')
# 7: 0:00:04.362000 - ('length_of_stay', 'review_group')
# 8: 0:00:02.876554 - ('length_of_stay', 'room_type')
# 9: 0:00:47.206017 - ('country', 'stay')
# 10: 0:00:44.418791 - ('country', 'length_of_stay')
# 11: 0:00:45.583035 - ('country', 'review_group')
# 12: 0:00:44.986655 - ('country', 'room_type')
# 13: 0:00:04.813688 - ('review_group', 'stay')
# 14: 0:00:03.672263 - ('review_group', 'length_of_stay')
# 15: 0:00:05.352265 - ('review_group', 'country')
# 16: 0:00:07.385300 - ('review_group', 'room_type')
# 17: 0:02:31.247381 - ('room_type', 'stay')
# 18: 0:02:32.487410 - ('room_type', 'length_of_stay')
# 19: 0:02:30.882460 - ('room_type', 'country')
# 20: 0:02:25.920745 - ('room_type', 'review_group')
# 21: 0:00:06.701705 - ('stay', 'length_of_stay', 'country')
# 22: 0:00:06.361851 - ('stay', 'length_of_stay', 'review_group')
# 23: 0:00:07.083157 - ('stay', 'length_of_stay', 'room_type')
# 24: 0:00:14.534634 - ('stay', 'country', 'length_of_stay')
# 25: 0:00:16.685571 - ('stay', 'country', 'review_group')
# 26: 0:00:14.702332 - ('stay', 'country', 'room_type')
# 27: 0:00:11.446572 - ('stay', 'review_group', 'length_of_stay')
# 28: 0:00:20.679762 - ('stay', 'review_group', 'country')
# 29: 0:00:21.970268 - ('stay', 'review_group', 'room_type')
# 30: 0:00:16.550011 - ('stay', 'room_type', 'length_of_stay')
# 31: 0:00:16.069536 - ('stay', 'room_type', 'country')
# 32: 0:00:18.034289 - ('stay', 'room_type', 'review_group')
# 33: 0:00:08.174605 - ('length_of_stay', 'stay', 'country')
# 34: 0:00:07.173659 - ('length_of_stay', 'stay', 'review_group')
# 35: 0:00:08.524761 - ('length_of_stay', 'stay', 'room_type')
# 36: 0:00:07.570055 - ('length_of_stay', 'country', 'stay')
# 37: 0:00:07.982346 - ('length_of_stay', 'country', 'review_group')
# 38: 0:00:06.993177 - ('length_of_stay', 'country', 'room_type')
# 39: 0:00:08.193721 - ('length_of_stay', 'review_group', 'stay')
# 40: 0:00:10.170407 - ('length_of_stay', 'review_group', 'country')
# 41: 0:00:09.960182 - ('length_of_stay', 'review_group', 'room_type')
# 42: 0:00:10.615370 - ('length_of_stay', 'room_type', 'stay')
# 43: 0:00:09.457631 - ('length_of_stay', 'room_type', 'country')
# 44: 0:00:10.956220 - ('length_of_stay', 'room_type', 'review_group')
# 45: 0:01:34.075889 - ('country', 'stay', 'length_of_stay')
# 46: 0:01:38.286644 - ('country', 'stay', 'review_group')
# 47: 0:01:49.260840 - ('country', 'stay', 'room_type')
# 48: 0:01:18.887330 - ('country', 'length_of_stay', 'stay')
# 49: 0:01:17.310940 - ('country', 'length_of_stay', 'review_group')
# 50: 0:01:32.644157 - ('country', 'length_of_stay', 'room_type')
# 51: 0:02:00.685320 - ('country', 'review_group', 'stay')
# 52: 0:01:51.395289 - ('country', 'review_group', 'length_of_stay')
# 53: 0:02:30.493956 - ('country', 'review_group', 'room_type')
# 54: 0:01:10.240244 - ('country', 'room_type', 'stay')
# 55: 0:01:12.939865 - ('country', 'room_type', 'length_of_stay')
# 56: 0:01:13.004471 - ('country', 'room_type', 'review_group')
# 57: 0:00:13.197038 - ('review_group', 'stay', 'length_of_stay')
# 58: 0:00:17.999050 - ('review_group', 'stay', 'country')
# 59: 0:00:19.366144 - ('review_group', 'stay', 'room_type')
# 60: 0:00:09.144666 - ('review_group', 'length_of_stay', 'stay')
# 61: 0:00:09.225863 - ('review_group', 'length_of_stay', 'country')
# 62: 0:00:10.261889 - ('review_group', 'length_of_stay', 'room_type')
# 63: 0:00:27.124142 - ('review_group', 'country', 'stay')
# 64: 0:00:24.666708 - ('review_group', 'country', 'length_of_stay')
# 65: 0:00:35.650288 - ('review_group', 'country', 'room_type')
# 66: 0:00:25.580062 - ('review_group', 'room_type', 'stay')
# 67: 0:00:25.410930 - ('review_group', 'room_type', 'length_of_stay')
# 68: 0:00:22.929127 - ('review_group', 'room_type', 'country')
# 69: 0:02:45.148616 - ('room_type', 'stay', 'length_of_stay')
# 70: 0:02:56.587263 - ('room_type', 'stay', 'country')
# 71: 0:02:55.106627 - ('room_type', 'stay', 'review_group')
# 72: 0:02:55.217581 - ('room_type', 'length_of_stay', 'stay')
# 73: 0:02:40.038352 - ('room_type', 'length_of_stay', 'country')
# 74: 0:02:40.061979 - ('room_type', 'length_of_stay', 'review_group')
# 75: 0:02:52.775394 - ('room_type', 'country', 'stay')
# 76: 0:02:34.857580 - ('room_type', 'country', 'length_of_stay')
# 77: 0:02:39.760696 - ('room_type', 'country', 'review_group')
# 78: 0:02:55.910023 - ('room_type', 'review_group', 'stay')
# 79: 0:03:00.846218 - ('room_type', 'review_group', 'length_of_stay')
# 80: 0:03:13.793148 - ('room_type', 'review_group', 'country')
# 81: 0:00:20.421827 - ('stay', 'length_of_stay', 'country', 'review_group')
# 82: 0:00:17.445216 - ('stay', 'length_of_stay', 'country', 'room_type')
# 83: 0:00:29.854002 - ('stay', 'length_of_stay', 'review_group', 'country')
# 84: 0:00:30.813807 - ('stay', 'length_of_stay', 'review_group', 'room_type')
# 85: 0:00:28.515621 - ('stay', 'length_of_stay', 'room_type', 'country')
# 86: 0:00:33.553842 - ('stay', 'length_of_stay', 'room_type', 'review_group')
# 87: 0:00:32.941484 - ('stay', 'country', 'length_of_stay', 'review_group')
# 88: 0:00:37.567075 - ('stay', 'country', 'length_of_stay', 'room_type')
# 89: 0:00:52.530883 - ('stay', 'country', 'review_group', 'length_of_stay')
# 90: 0:01:27.184723 - ('stay', 'country', 'review_group', 'room_type')
# 91: 0:00:27.912110 - ('stay', 'country', 'room_type', 'length_of_stay')
# 92: 0:00:30.484239 - ('stay', 'country', 'room_type', 'review_group')
# 93: 0:00:32.019721 - ('stay', 'review_group', 'length_of_stay', 'country')
# 94: 0:00:35.574920 - ('stay', 'review_group', 'length_of_stay', 'room_type')
# 95: 0:01:28.923188 - ('stay', 'review_group', 'country', 'length_of_stay')
# 96: 0:01:34.204568 - ('stay', 'review_group', 'country', 'room_type')
# 97: 0:01:26.423362 - ('stay', 'review_group', 'room_type', 'length_of_stay')
# 98: 0:01:25.071660 - ('stay', 'review_group', 'room_type', 'country')
# 99: 0:00:41.597186 - ('stay', 'room_type', 'length_of_stay', 'country')
# 100: 0:00:38.805581 - ('stay', 'room_type', 'length_of_stay', 'review_group')
# 101: 0:00:41.317801 - ('stay', 'room_type', 'country', 'length_of_stay')
# 102: 0:00:35.562688 - ('stay', 'room_type', 'country', 'review_group')
# 103: 0:01:05.656518 - ('stay', 'room_type', 'review_group', 'length_of_stay')
# 104: 0:01:39.036734 - ('stay', 'room_type', 'review_group', 'country')
# 105: 0:00:35.666428 - ('length_of_stay', 'stay', 'country', 'review_group')
# 106: 0:00:31.189071 - ('length_of_stay', 'stay', 'country', 'room_type')
# 107: 0:00:35.369186 - ('length_of_stay', 'stay', 'review_group', 'country')
# 108: 0:00:34.561078 - ('length_of_stay', 'stay', 'review_group', 'room_type')
# 109: 0:00:33.149170 - ('length_of_stay', 'stay', 'room_type', 'country')
# 110: 0:00:37.825418 - ('length_of_stay', 'stay', 'room_type', 'review_group')
# 111: 0:00:22.780980 - ('length_of_stay', 'country', 'stay', 'review_group')
# 112: 0:00:26.424975 - ('length_of_stay', 'country', 'stay', 'room_type')
# 113: 0:00:27.045598 - ('length_of_stay', 'country', 'review_group', 'stay')
# 114: 0:00:33.223765 - ('length_of_stay', 'country', 'review_group', 'room_type')
# 115: 0:00:14.226274 - ('length_of_stay', 'country', 'room_type', 'stay')
# 116: 0:00:15.158082 - ('length_of_stay', 'country', 'room_type', 'review_group')
# 117: 0:00:30.464399 - ('length_of_stay', 'review_group', 'stay', 'country')
# 118: 0:00:41.328232 - ('length_of_stay', 'review_group', 'stay', 'room_type')
# 119: 0:00:52.985864 - ('length_of_stay', 'review_group', 'country', 'stay')
# 120: 0:00:49.231743 - ('length_of_stay', 'review_group', 'country', 'room_type')
# 121: 0:00:50.275681 - ('length_of_stay', 'review_group', 'room_type', 'stay')
# 122: 0:00:45.978386 - ('length_of_stay', 'review_group', 'room_type', 'country')
# 123: 0:00:40.102083 - ('length_of_stay', 'room_type', 'stay', 'country')
# 124: 0:00:35.189576 - ('length_of_stay', 'room_type', 'stay', 'review_group')
# 125: 0:00:21.293316 - ('length_of_stay', 'room_type', 'country', 'stay')
# 126: 0:00:23.028200 - ('length_of_stay', 'room_type', 'country', 'review_group')
# 127: 0:00:45.175969 - ('length_of_stay', 'room_type', 'review_group', 'stay')
# 128: 0:01:01.474544 - ('length_of_stay', 'room_type', 'review_group', 'country')
# 129: 0:02:45.220133 - ('country', 'stay', 'length_of_stay', 'review_group')
# 130: 0:03:14.856263 - ('country', 'stay', 'length_of_stay', 'room_type')
# 131: 0:04:48.419414 - ('country', 'stay', 'review_group', 'length_of_stay')
# 132: 0:06:42.512336 - ('country', 'stay', 'review_group', 'room_type')
# 133: 0:06:37.589011 - ('country', 'stay', 'room_type', 'length_of_stay')
# 134: 0:07:05.347295 - ('country', 'stay', 'room_type', 'review_group')
# 135: 0:04:09.116733 - ('country', 'length_of_stay', 'stay', 'review_group')
# 136: 0:04:28.248089 - ('country', 'length_of_stay', 'stay', 'room_type')
# 137: 0:04:06.185164 - ('country', 'length_of_stay', 'review_group', 'stay')
# 138: 0:05:18.108082 - ('country', 'length_of_stay', 'review_group', 'room_type')
# 139: 0:05:52.922059 - ('country', 'length_of_stay', 'room_type', 'stay')
# 140: 0:06:03.707514 - ('country', 'length_of_stay', 'room_type', 'review_group')
# 141: 0:05:39.886033 - ('country', 'review_group', 'stay', 'length_of_stay')
# 142: 0:07:19.042422 - ('country', 'review_group', 'stay', 'room_type')
# 143: 0:04:03.553989 - ('country', 'review_group', 'length_of_stay', 'stay')
# 144: 0:04:34.787995 - ('country', 'review_group', 'length_of_stay', 'room_type')
# 145: 0:12:24.295947 - ('country', 'review_group', 'room_type', 'stay')
# 146: 0:11:46.310794 - ('country', 'review_group', 'room_type', 'length_of_stay')
# 147: 0:02:22.376904 - ('country', 'room_type', 'stay', 'length_of_stay')
# 148: 0:02:51.107449 - ('country', 'room_type', 'stay', 'review_group')
# 149: 0:01:55.763595 - ('country', 'room_type', 'length_of_stay', 'stay')
# 150: 0:02:00.084697 - ('country', 'room_type', 'length_of_stay', 'review_group')
# 151: 0:03:22.763240 - ('country', 'room_type', 'review_group', 'stay')
# 152: 0:02:59.208895 - ('country', 'room_type', 'review_group', 'length_of_stay')
# 153: 0:00:30.576411 - ('review_group', 'stay', 'length_of_stay', 'country')
# 154: 0:00:35.840439 - ('review_group', 'stay', 'length_of_stay', 'room_type')
# 155: 0:01:08.374110 - ('review_group', 'stay', 'country', 'length_of_stay')
# 156: 0:01:12.040215 - ('review_group', 'stay', 'country', 'room_type')
# 157: 0:01:34.987918 - ('review_group', 'stay', 'room_type', 'length_of_stay')
# 158: 0:01:15.316862 - ('review_group', 'stay', 'room_type', 'country')
# 159: 0:00:35.734301 - ('review_group', 'length_of_stay', 'stay', 'country')
# 160: 0:00:36.304061 - ('review_group', 'length_of_stay', 'stay', 'room_type')
# 161: 0:00:29.936619 - ('review_group', 'length_of_stay', 'country', 'stay')
# 162: 0:00:28.740583 - ('review_group', 'length_of_stay', 'country', 'room_type')
# 163: 0:00:47.236441 - ('review_group', 'length_of_stay', 'room_type', 'stay')
# 164: 0:00:42.217616 - ('review_group', 'length_of_stay', 'room_type', 'country')
# 165: 0:01:15.623502 - ('review_group', 'country', 'stay', 'length_of_stay')
# 166: 0:01:44.946420 - ('review_group', 'country', 'stay', 'room_type')
# 167: 0:00:56.356109 - ('review_group', 'country', 'length_of_stay', 'stay')
# 168: 0:01:09.665847 - ('review_group', 'country', 'length_of_stay', 'room_type')
# 169: 0:00:51.934942 - ('review_group', 'country', 'room_type', 'stay')
# 170: 0:00:49.535887 - ('review_group', 'country', 'room_type', 'length_of_stay')
# 171: 0:01:10.102543 - ('review_group', 'room_type', 'stay', 'length_of_stay')
# 172: 0:01:31.889101 - ('review_group', 'room_type', 'stay', 'country')
# 173: 0:00:55.288419 - ('review_group', 'room_type', 'length_of_stay', 'stay')
# 174: 0:00:57.338276 - ('review_group', 'room_type', 'length_of_stay', 'country')
# 175: 0:00:51.250662 - ('review_group', 'room_type', 'country', 'stay')
# 176: 0:00:47.873125 - ('review_group', 'room_type', 'country', 'length_of_stay')
# 177: 0:03:42.363196 - ('room_type', 'stay', 'length_of_stay', 'country')
# 178: 0:03:20.971000 - ('room_type', 'stay', 'length_of_stay', 'review_group')
# 179: 0:04:52.415778 - ('room_type', 'stay', 'country', 'length_of_stay')
# 180: 0:05:22.599754 - ('room_type', 'stay', 'country', 'review_group')
# 181: 0:04:35.867120 - ('room_type', 'stay', 'review_group', 'length_of_stay')
# 182: 0:05:55.150755 - ('room_type', 'stay', 'review_group', 'country')
# 183: 0:03:51.656646 - ('room_type', 'length_of_stay', 'stay', 'country')
# 184: 0:03:50.100702 - ('room_type', 'length_of_stay', 'stay', 'review_group')
# 185: 0:03:35.877918 - ('room_type', 'length_of_stay', 'country', 'stay')
# 186: 0:03:53.074804 - ('room_type', 'length_of_stay', 'country', 'review_group')
# 187: 0:03:57.101167 - ('room_type', 'length_of_stay', 'review_group', 'stay')
# 188: 0:04:08.630026 - ('room_type', 'length_of_stay', 'review_group', 'country')
# 189: 0:03:26.371231 - ('room_type', 'country', 'stay', 'length_of_stay')
# 190: 0:03:26.058830 - ('room_type', 'country', 'stay', 'review_group')
# 191: 0:02:59.654970 - ('room_type', 'country', 'length_of_stay', 'stay')
# 192: 0:03:05.952454 - ('room_type', 'country', 'length_of_stay', 'review_group')
# 193: 0:03:45.473449 - ('room_type', 'country', 'review_group', 'stay')
# 194: 0:03:33.820043 - ('room_type', 'country', 'review_group', 'length_of_stay')
# 195: 0:04:47.681634 - ('room_type', 'review_group', 'stay', 'length_of_stay')
# 196: 0:05:26.393181 - ('room_type', 'review_group', 'stay', 'country')
# 197: 0:04:20.895067 - ('room_type', 'review_group', 'length_of_stay', 'stay')
# 198: 0:03:57.869916 - ('room_type', 'review_group', 'length_of_stay', 'country')
# 199: 0:08:11.029806 - ('room_type', 'review_group', 'country', 'stay')
# 200: 0:07:14.732650 - ('room_type', 'review_group', 'country', 'length_of_stay')
# 201: 0:01:32.789087 - ('stay', 'length_of_stay', 'country', 'review_group', 'room_type')
# 202: 0:00:35.446454 - ('stay', 'length_of_stay', 'country', 'room_type', 'review_group')
# 203: 0:02:29.549486 - ('stay', 'length_of_stay', 'review_group', 'country', 'room_type')
# 204: 0:02:22.445948 - ('stay', 'length_of_stay', 'review_group', 'room_type', 'country')
# 205: 0:01:10.111305 - ('stay', 'length_of_stay', 'room_type', 'country', 'review_group')
# 206: 0:03:18.680726 - ('stay', 'length_of_stay', 'room_type', 'review_group', 'country')
# 207: 0:02:32.013724 - ('stay', 'country', 'length_of_stay', 'review_group', 'room_type')
# 208: 0:02:59.583883 - ('stay', 'country', 'length_of_stay', 'room_type', 'review_group')
# 209: 0:02:28.223926 - ('stay', 'country', 'review_group', 'length_of_stay', 'room_type')
# 210: 0:06:23.551603 - ('stay', 'country', 'review_group', 'room_type', 'length_of_stay')
# 211: 0:00:56.642145 - ('stay', 'country', 'room_type', 'length_of_stay', 'review_group')
# 212: 0:01:19.250014 - ('stay', 'country', 'room_type', 'review_group', 'length_of_stay')
# 213: 0:01:41.671499 - ('stay', 'review_group', 'length_of_stay', 'country', 'room_type')
# 214: 0:02:25.979583 - ('stay', 'review_group', 'length_of_stay', 'room_type', 'country')
# 215: 0:04:09.395348 - ('stay', 'review_group', 'country', 'length_of_stay', 'room_type')
# 216: 0:03:07.466900 - ('stay', 'review_group', 'country', 'room_type', 'length_of_stay')
# 217: 0:03:42.513056 - ('stay', 'review_group', 'room_type', 'length_of_stay', 'country')
# 218: 0:02:57.855835 - ('stay', 'review_group', 'room_type', 'country', 'length_of_stay')
# 219: 0:01:57.198936 - ('stay', 'room_type', 'length_of_stay', 'country', 'review_group')
# 220: 0:03:14.439439 - ('stay', 'room_type', 'length_of_stay', 'review_group', 'country')
# 221: 0:01:07.680587 - ('stay', 'room_type', 'country', 'length_of_stay', 'review_group')
# 222: 0:01:29.620164 - ('stay', 'room_type', 'country', 'review_group', 'length_of_stay')
# 223: 0:02:43.482937 - ('stay', 'room_type', 'review_group', 'length_of_stay', 'country')
# 224: 0:08:11.514212 - ('stay', 'room_type', 'review_group', 'country', 'length_of_stay')
# 225: 0:02:45.654739 - ('length_of_stay', 'stay', 'country', 'review_group', 'room_type')
# 226: 0:01:01.199061 - ('length_of_stay', 'stay', 'country', 'room_type', 'review_group')
# 227: 0:03:10.243102 - ('length_of_stay', 'stay', 'review_group', 'country', 'room_type')
# 228: 0:03:00.845844 - ('length_of_stay', 'stay', 'review_group', 'room_type', 'country')
# 229: 0:01:13.358724 - ('length_of_stay', 'stay', 'room_type', 'country', 'review_group')
# 230: 0:03:19.500471 - ('length_of_stay', 'stay', 'room_type', 'review_group', 'country')
# 231: 0:01:44.231976 - ('length_of_stay', 'country', 'stay', 'review_group', 'room_type')
# 232: 0:01:49.233294 - ('length_of_stay', 'country', 'stay', 'room_type', 'review_group')
# 233: 0:01:50.562748 - ('length_of_stay', 'country', 'review_group', 'stay', 'room_type')
# 234: 0:03:02.460940 - ('length_of_stay', 'country', 'review_group', 'room_type', 'stay')
# 235: 0:00:36.619369 - ('length_of_stay', 'country', 'room_type', 'stay', 'review_group')
# 236: 0:00:43.913749 - ('length_of_stay', 'country', 'room_type', 'review_group', 'stay')
# 237: 0:02:04.352219 - ('length_of_stay', 'review_group', 'stay', 'country', 'room_type')
# 238: 0:02:16.363888 - ('length_of_stay', 'review_group', 'stay', 'room_type', 'country')
# 239: 0:03:18.411289 - ('length_of_stay', 'review_group', 'country', 'stay', 'room_type')
# 240: 0:01:41.426906 - ('length_of_stay', 'review_group', 'country', 'room_type', 'stay')
# 241: 0:02:59.992906 - ('length_of_stay', 'review_group', 'room_type', 'stay', 'country')
# 242: 0:01:41.277294 - ('length_of_stay', 'review_group', 'room_type', 'country', 'stay')
# 243: 0:03:03.977667 - ('length_of_stay', 'room_type', 'stay', 'country', 'review_group')
# 244: 0:02:59.452926 - ('length_of_stay', 'room_type', 'stay', 'review_group', 'country')
# 245: 0:01:01.174094 - ('length_of_stay', 'room_type', 'country', 'stay', 'review_group')
# 246: 0:01:10.221211 - ('length_of_stay', 'room_type', 'country', 'review_group', 'stay')
# 247: 0:03:08.576775 - ('length_of_stay', 'room_type', 'review_group', 'stay', 'country')
# 248: 0:05:32.759222 - ('length_of_stay', 'room_type', 'review_group', 'country', 'stay')
# 249: 0:11:24.090637 - ('country', 'stay', 'length_of_stay', 'review_group', 'room_type')
# 250: 0:12:31.877943 - ('country', 'stay', 'length_of_stay', 'room_type', 'review_group')
# 251: 0:13:17.952764 - ('country', 'stay', 'review_group', 'length_of_stay', 'room_type')
# 252: 0:32:05.716430 - ('country', 'stay', 'review_group', 'room_type', 'length_of_stay')
# 253: 0:14:46.819118 - ('country', 'stay', 'room_type', 'length_of_stay', 'review_group')
# 254: 0:23:25.734656 - ('country', 'stay', 'room_type', 'review_group', 'length_of_stay')
# 255: 0:18:45.291119 - ('country', 'length_of_stay', 'stay', 'review_group', 'room_type')
# 256: 0:20:03.796661 - ('country', 'length_of_stay', 'stay', 'room_type', 'review_group')
# 257: 0:18:04.631757 - ('country', 'length_of_stay', 'review_group', 'stay', 'room_type')
# 258: 0:26:16.391427 - ('country', 'length_of_stay', 'review_group', 'room_type', 'stay')
# 259: 0:19:17.804383 - ('country', 'length_of_stay', 'room_type', 'stay', 'review_group')
# 260: 0:24:26.057647 - ('country', 'length_of_stay', 'room_type', 'review_group', 'stay')
# 261: 0:14:12.627062 - ('country', 'review_group', 'stay', 'length_of_stay', 'room_type')
# 262: 0:30:38.677255 - ('country', 'review_group', 'stay', 'room_type', 'length_of_stay')
# 263: 0:14:55.100339 - ('country', 'review_group', 'length_of_stay', 'stay', 'room_type')
# 264: 0:19:33.977346 - ('country', 'review_group', 'length_of_stay', 'room_type', 'stay')
# 265: 0:36:06.599699 - ('country', 'review_group', 'room_type', 'stay', 'length_of_stay')
# 266: 0:27:37.388316 - ('country', 'review_group', 'room_type', 'length_of_stay', 'stay')
# 267: 0:04:39.840840 - ('country', 'room_type', 'stay', 'length_of_stay', 'review_group')
# 268: 0:08:31.194336 - ('country', 'room_type', 'stay', 'review_group', 'length_of_stay')
# 269: 0:05:39.652138 - ('country', 'room_type', 'length_of_stay', 'stay', 'review_group')
# 270: 0:06:01.711430 - ('country', 'room_type', 'length_of_stay', 'review_group', 'stay')
# 271: 0:09:51.541375 - ('country', 'room_type', 'review_group', 'stay', 'length_of_stay')
# 272: 0:06:39.841656 - ('country', 'room_type', 'review_group', 'length_of_stay', 'stay')
# 273: 0:01:24.738722 - ('review_group', 'stay', 'length_of_stay', 'country', 'room_type')
# 274: 0:02:18.325936 - ('review_group', 'stay', 'length_of_stay', 'room_type', 'country')
# 275: 0:03:12.253406 - ('review_group', 'stay', 'country', 'length_of_stay', 'room_type')
# 276: 0:02:12.114374 - ('review_group', 'stay', 'country', 'room_type', 'length_of_stay')
# 277: 0:03:16.766052 - ('review_group', 'stay', 'room_type', 'length_of_stay', 'country')
# 278: 0:02:31.468822 - ('review_group', 'stay', 'room_type', 'country', 'length_of_stay')
# 279: 0:02:16.979280 - ('review_group', 'length_of_stay', 'stay', 'country', 'room_type')
# 280: 0:02:29.909027 - ('review_group', 'length_of_stay', 'stay', 'room_type', 'country')
# 281: 0:01:59.988054 - ('review_group', 'length_of_stay', 'country', 'stay', 'room_type')
# 282: 0:01:06.174153 - ('review_group', 'length_of_stay', 'country', 'room_type', 'stay')
# 283: 0:03:01.996317 - ('review_group', 'length_of_stay', 'room_type', 'stay', 'country')
# 284: 0:01:39.931408 - ('review_group', 'length_of_stay', 'room_type', 'country', 'stay')
# 285: 0:03:15.917476 - ('review_group', 'country', 'stay', 'length_of_stay', 'room_type')
# 286: 0:06:44.268779 - ('review_group', 'country', 'stay', 'room_type', 'length_of_stay')
# 287: 0:03:39.159919 - ('review_group', 'country', 'length_of_stay', 'stay', 'room_type')
# 288: 0:04:47.059585 - ('review_group', 'country', 'length_of_stay', 'room_type', 'stay')
# 289: 0:02:00.097258 - ('review_group', 'country', 'room_type', 'stay', 'length_of_stay')
# 290: 0:01:36.166039 - ('review_group', 'country', 'room_type', 'length_of_stay', 'stay')
# 291: 0:02:55.418821 - ('review_group', 'room_type', 'stay', 'length_of_stay', 'country')
# 292: 0:05:52.762886 - ('review_group', 'room_type', 'stay', 'country', 'length_of_stay')
# 293: 0:03:42.217234 - ('review_group', 'room_type', 'length_of_stay', 'stay', 'country')
# 294: 0:02:40.510007 - ('review_group', 'room_type', 'length_of_stay', 'country', 'stay')
# 295: 0:02:03.724825 - ('review_group', 'room_type', 'country', 'stay', 'length_of_stay')
# 296: 0:01:42.237746 - ('review_group', 'room_type', 'country', 'length_of_stay', 'stay')
# 297: 0:05:55.977627 - ('room_type', 'stay', 'length_of_stay', 'country', 'review_group')
# 298: 0:07:32.944791 - ('room_type', 'stay', 'length_of_stay', 'review_group', 'country')
# 299: 0:08:29.242524 - ('room_type', 'stay', 'country', 'length_of_stay', 'review_group')
# 300: 0:11:53.120874 - ('room_type', 'stay', 'country', 'review_group', 'length_of_stay')
# 301: 0:08:28.317337 - ('room_type', 'stay', 'review_group', 'length_of_stay', 'country')
# 302: 0:19:57.202348 - ('room_type', 'stay', 'review_group', 'country', 'length_of_stay')
# 303: 0:09:27.754419 - ('room_type', 'length_of_stay', 'stay', 'country', 'review_group')
# 304: 0:10:32.415931 - ('room_type', 'length_of_stay', 'stay', 'review_group', 'country')
# 305: 0:06:39.014939 - ('room_type', 'length_of_stay', 'country', 'stay', 'review_group')
# 306: 0:07:02.813871 - ('room_type', 'length_of_stay', 'country', 'review_group', 'stay')
# 307: 0:08:48.974716 - ('room_type', 'length_of_stay', 'review_group', 'stay', 'country')
# 308: 0:13:49.111552 - ('room_type', 'length_of_stay', 'review_group', 'country', 'stay')
# 309: 0:04:40.997676 - ('room_type', 'country', 'stay', 'length_of_stay', 'review_group')
# 310: 0:06:27.746838 - ('room_type', 'country', 'stay', 'review_group', 'length_of_stay')
# 311: 0:04:53.136568 - ('room_type', 'country', 'length_of_stay', 'stay', 'review_group')
# 312: 0:05:05.581382 - ('room_type', 'country', 'length_of_stay', 'review_group', 'stay')
# 313: 0:06:32.603421 - ('room_type', 'country', 'review_group', 'stay', 'length_of_stay')
# 314: 0:05:24.470294 - ('room_type', 'country', 'review_group', 'length_of_stay', 'stay')
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\users\zekzi\venv\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# c:\users\zekzi\venv\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# c:\users\zekzi\venv\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#
# OSError: [WinError 10065] A socket operation was attempted to an unreachable host
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# c:\users\zekzi\venv\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# c:\users\zekzi\venv\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397             else:
# --> 398                 conn.request(method, url, **httplib_request_kw)
#     399
#
# c:\users\zekzi\venv\lib\site-packages\urllib3\connection.py in request(self, method, url, body, headers)
#     238             headers["User-Agent"] = _get_default_user_agent()
# --> 239         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     240
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1330             body = _encode(body, 'body')
# -> 1331         self.endheaders(body, encode_chunked=encode_chunked)
#    1332
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1279             raise CannotSendHeader()
# -> 1280         self._send_output(message_body, encode_chunked=encode_chunked)
#    1281
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1039         del self._buffer[:]
# -> 1040         self.send(msg)
#    1041
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\http\client.py in send(self, data)
#     979             if self.auto_open:
# --> 980                 self.connect()
#     981             else:
#
# c:\users\zekzi\venv\lib\site-packages\urllib3\connection.py in connect(self)
#     204     def connect(self):
# --> 205         conn = self._new_conn()
#     206         self._prepare_conn(conn)
#
# c:\users\zekzi\venv\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000021549C0A880>: Failed to establish a new connection: [WinError 10065] A socket operation was attempted to an unreachable host
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\users\zekzi\venv\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439             if not chunked:
# --> 440                 resp = conn.urlopen(
#     441                     method=request.method,
#
# c:\users\zekzi\venv\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     784
# --> 785             retries = retries.increment(
#     786                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# c:\users\zekzi\venv\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#
# MaxRetryError: HTTPConnectionPool(host='34.124.232.97', port=9000): Max retries exceeded with url: /rules/dss?antecedents=length_of_stay%3A1-7&consequents=country&hotel_name=Amari+Phuket (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000021549C0A880>: Failed to establish a new connection: [WinError 10065] A socket operation was attempted to an unreachable host'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35892/574780788.py in <module>
#      31     gen_count += 1
#      32     a = datetime.datetime.now()
# ---> 33     root_node = generate_decision_tree(mcda_type, list(permutation), weights, hotel_name=hotel_name,
#      34                                        rule_year=rule_year, rule_month=rule_month)
#      35     b = datetime.datetime.now()
#
# ~\Projects\DecisionTree\research-dss-result\controller.py in generate_decision_tree(mcda_type, factors, manual_weights, hotel_name, rule_year, rule_month)
#      26                       sorted(zip(computed_weights, factors), key=lambda pair: pair[0], reverse=True)]
#      27
# ---> 28     accumulate_node(root, sorted_factors, hotel_name=hotel_name, rule_year=rule_year, rule_month=rule_month)
#      29     apply_freq_by_path(root, hotel_name=hotel_name, DB=DB)
#      30     apply_weight_by_node_level(root, sorted_weights)
#
# ~\Projects\DecisionTree\research-dss-result\tree_from_assoc_rules.py in accumulate_node(node, factors, depth, hotel_name, rule_year, rule_month)
#      30         for entity in entities:
#      31             new_node = AnyNode(id=uuid.uuid4().hex, name=entity, parent=node, level=depth, weight=None, score=None)
# ---> 32             accumulate_node(new_node, next_factors, depth + 1, hotel_name=hotel_name, rule_year=rule_year, rule_month=rule_month)
#      33     else:
#      34         # AnyNode(id=uuid.uuid4().hex, name="Leaf node", parent=node)
#
# ~\Projects\DecisionTree\research-dss-result\tree_from_assoc_rules.py in accumulate_node(node, factors, depth, hotel_name, rule_year, rule_month)
#      38             r = rule[0]
#      39             new_node = AnyNode(id=uuid.uuid4().hex, name=r["consequents"], parent=node, level=depth, confidence=r["confidence"], lift=r["lift"])
# ---> 40             accumulate_node(new_node, next_factors, depth + 1, hotel_name=hotel_name, rule_year=rule_year, rule_month=rule_month)
#      41
#      42
#
# ~\Projects\DecisionTree\research-dss-result\tree_from_assoc_rules.py in accumulate_node(node, factors, depth, hotel_name, rule_year, rule_month)
#      38             r = rule[0]
#      39             new_node = AnyNode(id=uuid.uuid4().hex, name=r["consequents"], parent=node, level=depth, confidence=r["confidence"], lift=r["lift"])
# ---> 40             accumulate_node(new_node, next_factors, depth + 1, hotel_name=hotel_name, rule_year=rule_year, rule_month=rule_month)
#      41
#      42
#
# ~\Projects\DecisionTree\research-dss-result\tree_from_assoc_rules.py in accumulate_node(node, factors, depth, hotel_name, rule_year, rule_month)
#      38             r = rule[0]
#      39             new_node = AnyNode(id=uuid.uuid4().hex, name=r["consequents"], parent=node, level=depth, confidence=r["confidence"], lift=r["lift"])
# ---> 40             accumulate_node(new_node, next_factors, depth + 1, hotel_name=hotel_name, rule_year=rule_year, rule_month=rule_month)
#      41
#      42
#
# ~\Projects\DecisionTree\research-dss-result\tree_from_assoc_rules.py in accumulate_node(node, factors, depth, hotel_name, rule_year, rule_month)
#      33     else:
#      34         # AnyNode(id=uuid.uuid4().hex, name="Leaf node", parent=node)
# ---> 35         rules = __fetch_assoc_rule(node.name, current_factor, hotel_name=hotel_name, rule_year=rule_year, rule_month=rule_month)
#      36         rules = __find_unique(rules)
#      37         for rule in rules:
#
# ~\Projects\DecisionTree\research-dss-result\tree_from_assoc_rules.py in __fetch_assoc_rule(lhs, rhs, hotel_name, rule_year, rule_month)
#      97     payload = {'antecedents': lhs, 'consequents': rhs, 'hotel_name': hotel_name, 'rule_year': rule_year,
#      98                'rule_month': rule_month}
# ---> 99     r = requests.get(ASSOC_RULE_BASE_URL + "/rules/dss", params=payload)
#     100     return r.json()
#     101
#
# c:\users\zekzi\venv\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\users\zekzi\venv\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\users\zekzi\venv\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# c:\users\zekzi\venv\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# c:\users\zekzi\venv\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     517                 raise SSLError(e, request=request)
#     518
# --> 519             raise ConnectionError(e, request=request)
#     520
#     521         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='34.124.232.97', port=9000): Max retries exceeded with url: /rules/dss?antecedents=length_of_stay%3A1-7&consequents=country&hotel_name=Amari+Phuket (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000021549C0A880>: Failed to establish a new connection: [WinError 10065] A socket operation was attempted to an unreachable host'))

# %%
import csv

# print(tabulate(result_score_table, headers='firstrow', tablefmt='fancy_grid'))
with open("out.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(result_score_table)
